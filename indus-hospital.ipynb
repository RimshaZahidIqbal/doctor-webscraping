# %%
from bs4 import BeautifulSoup
import json

data = """
<table id="tablepress-5" class="tablepress tablepress-id-5 dataTable no-footer" aria-describedby="tablepress-5_info">
<thead>
<tr class="row-1 odd"><th class="column-1 sorting" tabindex="0" aria-controls="tablepress-5" rowspan="1" colspan="1" aria-label="EMPLOYEE NAME: activate to sort column ascending" style="width: 256.469px;"><strong>EMPLOYEE NAME</strong></th><th class="column-2 sorting" tabindex="0" aria-controls="tablepress-5" rowspan="1" colspan="1" aria-label="POSITION: activate to sort column ascending" style="width: 244.609px;"><strong>POSITION</strong></th><th class="column-3 sorting" tabindex="0" aria-controls="tablepress-5" rowspan="1" colspan="1" aria-label="SERVICE LINE: activate to sort column ascending" style="width: 318.922px;"><strong>SERVICE LINE</strong></th><th class="column-4 sorting" tabindex="0" aria-controls="tablepress-5" rowspan="1" colspan="1" aria-label="DEPARTMENT: activate to sort column ascending" style="width: 411px;"><strong>DEPARTMENT</strong></th></tr>
</thead>
<tbody class="row-hover">
<tr class="row-15 even">
	<td class="column-1">Dr. Quratulain Bushra Noor</td><td class="column-2">Senior Registrar</td><td class="column-3">Emergency Services</td><td class="column-4">Pediatric Emergency Medicine</td>
</tr><tr class="row-16 odd">
	<td class="column-1">Dr. Saba Laila Aslam</td><td class="column-2">Consultant</td><td class="column-3">Emergency Services</td><td class="column-4">Pediatric Emergency Medicine</td>
</tr><tr class="row-68 even">
	<td class="column-1">Dr. Abdul Rahim Ahmed</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Intensive Care</td>
</tr><tr class="row-69 odd">
	<td class="column-1">Dr. Arjamand Shauq</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Cardiology</td>
</tr><tr class="row-70 even">
	<td class="column-1">Dr. Farhana Amanullah</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Medicine</td>
</tr><tr class="row-71 odd">
	<td class="column-1">Dr. Fatima Ambreen Imran</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Oncology</td>
</tr><tr class="row-72 even">
	<td class="column-1">Dr. Ghulam Qadir Pathan</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Oncology</td>
</tr><tr class="row-73 odd">
	<td class="column-1">Dr. Hana Arbab</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric General Surgery</td>
</tr><tr class="row-74 even">
	<td class="column-1">Dr. Humaira Jurair</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Intensive Care</td>
</tr><tr class="row-75 odd">
	<td class="column-1">Dr. Maryam Aftab</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric General Surgery</td>
</tr><tr class="row-76 even">
	<td class="column-1">Dr. Muhammad Fareeduddin</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Medicine</td>
</tr><tr class="row-77 odd">
	<td class="column-1">Dr. Muhammad Rafie Raza</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Oncology</td>
</tr><tr class="row-78 even">
	<td class="column-1">Dr. Naila Sehar</td><td class="column-2">Senior Registrar</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Oncology</td>
</tr><tr class="row-79 odd">
	<td class="column-1">Dr. Quratulain Riaz</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Oncology</td>
</tr><tr class="row-80 even">
	<td class="column-1">Dr. Rukhsana Syed</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Medicine</td>
</tr><tr class="row-81 odd">
	<td class="column-1">Dr. Saba Shahid</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Medicine</td>
</tr><tr class="row-82 even">
	<td class="column-1">Dr. Sadia Imran</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Oncology</td>
</tr><tr class="row-83 odd">
	<td class="column-1">Dr. Sadiq Mirza</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Intensive Care</td>
</tr><tr class="row-84 even">
	<td class="column-1">Dr. Samina Junejo</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Medicine</td>
</tr><tr class="row-85 odd">
	<td class="column-1">Dr. Sana</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Neonatal Medicine</td>
</tr><tr class="row-86 even">
	<td class="column-1">Dr. Sindhu</td><td class="column-2">Senior Registrar</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Medicine</td>
</tr><tr class="row-87 odd">
	<td class="column-1">Dr. Suresh Kumar</td><td class="column-2">Senior Registrar</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric General Surgery</td>
</tr><tr class="row-88 even">
	<td class="column-1">Dr. Syed Ahmer Hamid</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Pediatric Oncology</td>
</tr><tr class="row-89 odd">
	<td class="column-1">Dr. Syed Muzaffar Saleem</td><td class="column-2">Senior Registrar</td><td class="column-3">Pediatric Services</td><td class="column-4">Neonatal Medicine</td>
</tr><tr class="row-90 even">
	<td class="column-1">Dr. Vikram Kumar</td><td class="column-2">Consultant</td><td class="column-3">Pediatric Services</td><td class="column-4">Neonatal Medicine</td>
</tr></tbody>
</table>
"""

# URL of the page with the table

soup = BeautifulSoup(data, 'html.parser')

# Find the table
table = soup.find('table', {'id': 'tablepress-5'})

# Extract table headers
headers = [header.get_text(strip=True) for header in table.find_all('th')]

# Extract rows
rows = table.find('tbody').find_all('tr')

# Extract doctor data
doctors = []
for row in rows:
    columns = row.find_all('td')
    if len(columns) == len(headers):  # Ensure row has correct number of columns
        doctor_info = {
            'name': columns[0].get_text(strip=True),
            'position': columns[1].get_text(strip=True),
            'service_line': columns[2].get_text(strip=True),
            'department': columns[3].get_text(strip=True),
        }
        doctors.append(doctor_info)

# Print extracted information
print(doctors)

# Save in JSON format

output_path = 'outputs/indus-hospital.json'
# Write updated data to the JSON file
with open(output_path, 'w') as json_file:
    json.dump(output_path, json_file, indent=4)
# Out:
# [{'name': 'Dr. Quratulain Bushra Noor', 'position': 'Senior Registrar', 'service_line': 'Emergency Services', 'department': 'Pediatric Emergency Medicine'}, {'name': 'Dr. Saba Laila Aslam', 'position': 'Consultant', 'service_line': 'Emergency Services', 'department': 'Pediatric Emergency Medicine'}, {'name': 'Dr. Abdul Rahim Ahmed', 'position': 'Consultant', 'service_line': 'Pediatric Services', 'department': 'Pediatric Intensive Care'}, {'name': 'Dr. Arjamand Shauq', 'position': 'Consultant', 'service_line': 'Pediatric Services', 'department': 'Pediatric Cardiology'}, {'name': 'Dr. Farhana Amanullah', 'position': 'Consultant', 'service_line': 'Pediatric Services', 'department': 'Pediatric Medicine'}, {'name': 'Dr. Fatima Ambreen Imran', 'position': 'Consultant', 'service_line': 'Pediatric Services', 'department': 'Pediatric Oncology'}, {'name': 'Dr. Ghulam Qadir Pathan', 'position': 'Consultant', 'service_line': 'Pediatric Services', 'department': 'Pediatric Oncology'}, {'name': 'Dr
# ...
